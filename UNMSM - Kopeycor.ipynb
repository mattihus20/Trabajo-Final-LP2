# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse

## PRIMERA PARTE DEL CÓDIGO

# URL del repositorio PUCP: tesis de Ingeniería Informática
url = 'http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions'
parsed_url = urlparse(url)

# Hacer solicitud HTTP a la URL y obtener el contenido HTML
response = requests.get(url)
html = response.content

# Procesar el HTML con BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# Buscamos 
ps = soup.find('a', class_ = 'next-page-link').get('href')

# Obtiene el dominio principal
domain = parsed_url.netloc

# Obtiene el esquema
scheme = parsed_url.scheme

# Construye el URL del dominio principal
url2 = f'{scheme}://{domain}'

lista = []
lista.append(url)
url3 = None
i = 0
while lista[-1] != url2:
    
    url3 = lista[i]

    # Solicitud
    r = requests.get(url3)
    h = r.content
    
    # Procesar
    s = BeautifulSoup(h, 'html.parser')
    
    # Buscamos
    p = s.find('a', class_ = 'next-page-link').get('href')
    
    # Agregamos a la lista
    lista.append(url2 + p)
    #print(lista)
    i += 1

lista.pop(-1)

## SEGUNDA PARTE DEL CÓDIGO

handle = []

for i in lista:
    # URL del repositorio PUCP: tesis de Ingeniería Informática
    url4 = i

    # Hacer solicitud HTTP a la URL y obtener el contenido HTML
    response2 = requests.get(url4)
    html2 = response2.content

    # Procesar el HTML con BeautifulSoup
    soup2 = BeautifulSoup(html2, 'html.parser')

    # Extraer todos los enlaces con la etiqueta <h4>
    h4s = soup2.find_all('h4')

    # Iterar sobre cada etiqueta <h4>
    for h4 in h4s:
        # Extraer el enlace de la etiqueta <a> dentro de la etiqueta <h4>
        link = h4.find('a').get('href')
        handle.append(link)

## TERCERA PARTE DEL CÓDIGO

etiquetas = []
rutas = []

for j in handle:
    
    # Obtén el contenido HTML de la página web
    url5 = url2 + j
    page3 = requests.get(url5)
    soup3 = BeautifulSoup(page3.content, 'html.parser')
    # Buscar todos los enlaces que tengan el texto "Show full item record"
    enlaces = soup3.find_all('a', text='Mostrar el registro completo del ítem')

    # Si se encontraron enlaces, obtener el valor del atributo href del primer enlace
    if enlaces:
        href = enlaces[0]['href']
        rutas.append(href)  # imprime el valor del atributo href

## CUARTA PARTE DEL CÓDIGO

universidad = []
titulo = []
autor = []
grado = []
asesor = []
resumen = []
anio = []

v = ['dc.publisher','dc.title','dc.contributor.author','thesis.degree.name','dc.contributor.advisor',
    'dc.description.abstract','dc.date.issued']

for o in rutas:

    q = url2 + o
    p = requests.get(q)
    ss = BeautifulSoup(p.content, 'html.parser')
    ls = ss.find_all('td', class_= 'label-cell')
    tds = ss.find_all('td', class_= 'word-break')

    m = []
    for td in tds:
        c = td.text
        m.append(c)

    l = []
    for g in ls:
        u = g.text
        l.append(u)
    
    diccionario = dict(zip(l,m))
  
    if v[0] in diccionario:
        universidad.append(diccionario[v[0]])
    else:
        universidad.append('Sin registro')

    if v[1] in diccionario:
        titulo.append(diccionario[v[1]])
    else:
        titulo.append('Sin registro')

    if v[2] in diccionario:
        autor.append(diccionario[v[2]])
    else:
        autor.append('Sin registro')

    if v[3] in diccionario:
        grado.append(diccionario[v[3]])
    else:
        grado.append('Sin registro')

    if v[4] in diccionario:
        asesor.append(diccionario[v[4]])
    else:
        asesor.append('Sin registro')

    if v[5] in diccionario:
        resumen.append(diccionario[v[5]])
    else:
        resumen.append('Sin registro')

    if v[6] in diccionario:
        anio.append(diccionario[v[6]])
    else:
        anio.append('Sin registro')

        

datos = {
    'Universidad': universidad,
    'Titulo': titulo,
    'Autor': autor,
    'Grado': grado,
    'Asesor': asesor,
    'Resumen': resumen,
    'Año': anio
}

df = pd.DataFrame(datos)
df.to_csv('unmsm.csv', sep = ';', index = False ,encoding = 'utf-8')

# %%
handle = []

for i in lista:
    # URL del repositorio PUCP: tesis de Ingeniería Informática
    url4 = i
    print(url4)
    # Hacer solicitud HTTP a la URL y obtener el contenido HTML
    response2 = requests.get(url4)
    html2 = response2.content

    # Procesar el HTML con BeautifulSoup
    soup2 = BeautifulSoup(html2, 'html.parser')

    # Extraer todos los enlaces con la etiqueta <h4>
    h4s = soup2.find_all('h4')

    # Iterar sobre cada etiqueta <h4>
    for h4 in h4s:
        # Extraer el enlace de la etiqueta <a> dentro de la etiqueta <h4>
        link = h4.find('a').get('href')
        handle.append(link)
print(handle)
# Out:
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=20
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=40
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=60
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=80
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=100
# http://cybertesis.unmsm.edu.pe/handle/20.500.12672/5100/recent-submissions?offset=120
# ['/handle/20.500.12672/18913', '/handle/20.500.12672/18682', '/handle/20.500.12672/18681', '/handle/20.500.12672/18668', '/handle/20.500.12672/18663', '/handle/20.500.12672/18655', '/handle/20.500.12672/18654', '/handle/20.500.12672/18660', '/handle/20.500.12672/18631', '/handle/20.500.12672/18624', '/handle/20.500.12672/18608', '/handle/20.500.12672/18614', '/handle/20.500.12672/18595', '/handle/20.500.12672/18593', '/handle/20.500.12672/18589', '/handle/20.500.12672/18579', '/handle/20.500.12672/18226', '/handle/20.500.12672/17622', '/handle/20.500.12672/17547', '/handle/20.500.12672/17530', '/handle/20.500.12672/17521', '/handle/20.500.12672/17402', '/handle/20.500.12672/17395', '/handle/20.500.12672/17379', '/handle/20.500.12672/17372', '/handle/20.500.12672/17359', '/handle/20.500.12672/17342', '/handle/20.500.12672/17340', '/handle/20.500.12672/17339', '/handle/20.500.12672/17331', '/handle/20.500.12672/17282', '/handle/20.500.12672/17028', '/handle/20.500.12672/16835', '/handle/20.500.12672/16810', '/handle/20.500.12672/16400', '/handle/20.500.12672/16311', '/handle/20.500.12672/16278', '/handle/20.500.12672/15809', '/handle/20.500.12672/15737', '/handle/20.500.12672/15667', '/handle/20.500.12672/15632', '/handle/20.500.12672/15333', '/handle/20.500.12672/15330', '/handle/20.500.12672/15326', '/handle/20.500.12672/15323', '/handle/20.500.12672/15322', '/handle/20.500.12672/15297', '/handle/20.500.12672/15173', '/handle/20.500.12672/15111', '/handle/20.500.12672/15101', '/handle/20.500.12672/15093', '/handle/20.500.12672/15097', '/handle/20.500.12672/14875', '/handle/20.500.12672/14868', '/handle/20.500.12672/14849', '/handle/20.500.12672/14574', '/handle/20.500.12672/14464', '/handle/20.500.12672/14459', '/handle/20.500.12672/14414', '/handle/20.500.12672/14259', '/handle/20.500.12672/14125', '/handle/20.500.12672/13983', '/handle/20.500.12672/12724', '/handle/20.500.12672/12428', '/handle/20.500.12672/12354', '/handle/20.500.12672/12255', '/handle/20.500.12672/12233', '/handle/20.500.12672/12178', '/handle/20.500.12672/12143', '/handle/20.500.12672/12128', '/handle/20.500.12672/11985', '/handle/20.500.12672/11988', '/handle/20.500.12672/11835', '/handle/20.500.12672/11791', '/handle/20.500.12672/11543', '/handle/20.500.12672/11252', '/handle/20.500.12672/11006', '/handle/20.500.12672/10671', '/handle/20.500.12672/10559', '/handle/20
# 138    Gonzales King-Keé, Karin Cecilia  Licenciado en Estadística
# 139        Flores Flores, Claudio Jaime  Licenciado en Estadística
#
#                            Asesor  \
# 0    Molina Quiñones, Helfer Joel
# 1    Molina Quiñones, Helfer Joel
# 2           Roque Paredes, Ofelia
# 3           Roque Paredes, Ofelia
# 4    Molina Quiñones, Helfer Joel
# ..                            ...
# 135   Cambillo Moyano, Emma Norma
# 136   Gómez Ticerán, Doris Albina
# 137   Gómez Ticerán, Doris Albina
# 138                  Sin registro
# 139         Bravo Quiroz, Antonio
#
#                                                Resumen   Año
# 0    Aborda como principal estudio conocer los fact...  2022
# 1    Determina las tasas de años de vida potencialm...  2022
# 2    En tiempos actuales, los ecommerce se han conv...  2022
# 3    Desea captar la mayor cantidad de audiencia me...  2022
# 4    Evalua las alertas que se han presentado en el...  2022
# ..                                                 ...   ...
# 135  --- Two classics methods of classification are...  2010
# 136  --- This research addresses the problem of lac...  2012
# 137  -- We present measures to detect and identify ...  2010
# 138  -- In this work the metod of weighted least sq...  2001
# 139  -- In many clinical studies, Cox proportional ...  2011
#
# [140 rows x 7 columns]

# %%
df2 = df[df['Asesor'] == 'Sin registro']
print(len(df2))
# Out:
# 19

# %%
df3 = df.groupby('Asesor')['Asesor'].count()

df3_ordenado = df3.sort_values(ascending=False)

print(df3_ordenado)
# Out:
# Asesor
# Sin registro                                      19
# Roque Paredes, Ofelia                             12
# Solano Dávila, Olga Lidia                         11
# Cambillo Moyano, Emma Norma                       10
# Molina Quiñones, Helfer Joel                       7
# Kraenau Espinal, Erwin                             7
# Ponce Aruneri, María Estela                        7
# Montes Quintana de Domínguez, Grabiela Yolanda     7
# Nolberto Sifuentes, Violeta Alicia                 6
# Agüero Palacios, Ysela Dominga                     6
# Medina Merino, Rosa Fátima                         6
# Adriazola Cruz, Rosa Ysabel                        6
# Bravo Quiroz, Antonio                              5
# Gómez Ticerán, Doris Albina                        4
# Ramos Ramírez, Julio César                         3
# Domínguez Cirilo, Wilfredo Eugenio                 3
# Fiestas Flores, Roberto Carlos                     2
# Robles Villanueva, Oscar Antonio                   2
# Vallenas Ochoa, Justo Guillermo                    1
# Ticse Núñez, Cornelio Vicente                      1
# Camones Gonzales, Fernando Cesar                   1
# Santos Falcón, Gladys Carmela                      1
# Canales del Mar, Manuel Rolando                    1
# Rodriguez Orellana, Hugo Marino                    1
# Pomalaya Verástegui, Ricardo Luis                  1
# Cañari Casaño, Edilberto Daniel                    1
# Huamán Gutierrez, Zoraida Judith                   1
# Pillhuaman Caña, Nelly Demetria                    1
# Norabuena Figueroa, Roger Pedro                    1
# Cárdenas Rojas de Peche, Ana María                 1
# Navarro Huamaní, Luis Alberto                      1
# Fiesta Flores, Roberto Carlos                      1
# Fiesta Flores, Roberto carlos                      1
# Huamán Gutiérrez, Zoraida Judith                   1
# Vigo Chacón, Geraldine Judith                      1
# Name: Asesor, dtype: int64

# %%
df4 = df.groupby('Año')['Año'].count()

df4_ordenado = df4.sort_values(ascending=False)

print(df4_ordenado)
# Out:
# Año
# 2016    22
# 2021    20
# 2022    14
# 2009    10
# 2017     9
# 2012     9
# 2011     8
# 2008     8
# 2013     7
# 2010     7
# 2014     4
# 2007     4
# 2003     3
# 2015     3
# 2005     3
# 2018     3
# 2019     3
# 2020     1
# 2004     1
# 2001     1
# Name: Año, dtype: int64
